# %%
INPUT_FILE_PATH = './data/input1.txt'
MAX_VALUE = 99999999

N, M = 0, 0
t, g, s, c = [], [], [], []

def read_input(file_name):
    global N, M, t, g, s, c

    with open(file_name) as file:
        lines = [line.rstrip() for line in file]

    N, M = tuple(int(x) for x in lines[0].split())

    for i in range(N):
        num_periods, teacher, num_pupils = tuple(int(x) for x in lines[i+1].split())
        t.append(num_periods)
        g.append(teacher)
        s.append(num_pupils)

    c = [int(x) for x in lines[-1].split()]

    if len(t) != N or len(g) != N or len(s) != N or len(c) != M:
        raise Exception('Error when reading data!')

read_input(INPUT_FILE_PATH)

N, M, t, g, s, c
# Out:
# (500,
#  50,
#  [4,
#   3,
#   3,
#   4,
#   3,
#   3,
#   2,
#   4,
#   2,
#   3,
#   2,
#   4,
#   4,
#   4,
#   3,
#   2,
#   2,
#   2,
#   4,
#   4,
#   2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   3,
#   2,
#   4,
#   3,
#   2,
#   3,
#   3,
#   2,
#   4,
#   4,
#   4,
#   3,
#   4,
#   2,
#   2,
#   2,
#   3,
#   2,
#   4,
#   4,
#   3,
#   2,
#   2,
#   2,
#   3,
#   2,
#   2,
#   2,
#   4,
#   3,
#   3,
#   4,
#   4,
#   3,
#   2,
#   2,
#   3,
#   4,
#   3,
#   3,
#   4,
#   4,
#   2,
#   2,
#   2,
#   3,
#   3,
#   2,
#   4,
#   2,
#   3,
#   4,
#   4,
#   2,
#   3,
#   4,
#   2,
#   4,
#   2,
#   4,
#   4,
#   4,
#   2,
#   3,
#   2,
#   4,
#   4,
#   3,
#   2,
#   3,
#   3,
#   3,
#   4,
#   3,
#   3,
#   2,
#   2,
#   4,
#   3,
#   4,
#   3,
#   3,
#   2,
#   4,
#   3,
#   4,
#   3,
#   4,
#   4,
#   4,
#   3,
#   3,
#   3,
#   4,
#   2,
#   3,
#   3,
#   4,
#   3,
#   3,
#   3,
#   3,
#   3,
#   3,
#   4,
#   3,
#   2,
#   3,
#   2,
#   2,
#   3,
#   2,
#   4,
#   4,
#   3,
#   2,
#   3,
#   3,
#   3,
#   3,
#   4,
#   4,
#   2,
#   3,
#   2,
#   4,
#   2,
#   4,
#   2,
#   3,
#   4,
#   2,
#   4,
#   2,
#   2,
#   3,
#   2,
#   4,
#   2,
#   2,
#   3,
#   4,
#   2,
#   3,
#   4,
#   4,
#   4,
#   3,
#   4,
#   3,
#   2,
#   3,
#   4,
#   3,
#   4,
#   4,
#   4,
#   4,
#   2,
#   4,
#   2,
#   3,
#   4,
#   3,
#   4,
#   4,
#   4,
#   3,
#   3,
#   2,
#   4,
#   3,
#   3,
#   2,
#   2,
#   4,
#   2,
#   3,
#   2,
#   2,
#   4,
#   2,
#   3,
#   2,
#   2,
#   4,
#   3,
#   3,
#   2,
#   4,
#   4,
#   2,
#   2,
#   3,
#   4,
#   2,
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   3,
#   4,
#   4,
#   3,
#   4,
#   2,
#   3,
#   4,
#   2,
#   2,
#   2,
#   3,
#   2,
#   2,
#   2,
#   3,
#   2,
#   2,
#   3,
#   4,
#   4,
#   3,
#   3,
#   4,
#   2,
#   2,
#   3,
#   3,
#   3,
#   4,
#   2,
#   4,
#   3,
#   3,
#   2,
#   2,
#   3,
#   4,
#   4,
#   2,
#   2,
#   3,
#   4,
#   2,
#   3,
#   3,
#   2,
#   4,
#   4,
#   2,
#   4,
#   4,
#   4,
#   2,
#   4,
#   4,
#   4,
#   4,
#   4,
#   2,
#   4,
#   4,
#   3,
#   3,
#   4,
#   3,
#   2,
#   3,
#   2,
#   2,
#   2,
#   2,
#   2,
#   2,
#   4,
#   3,
#   4,
#   2,
#   3,
#   3,
#   2,
#   2,
#   2,
#   2,
#   2,
#   3,
#   3,
#   4,
#   4,
#   2,
#   4,
#   2,
#   4,
#   4,
#   2,
#   2,
#   3,
#   2,
#   2,
#   4,
#   3,
#   2,
#   4,
#   2,
#   2,
#   2,
#   4,
#   3,
#   4,
#   4,
#   3,
#   4,
#   4,
#   2,
#   2,
#   3,
#   3,
#   2,
#   4,
#   2,
#   3,
#   2,
#   3,
#   2,
#   3,
#   2,
#   3,
#   3,
#   4,
#   3,
#   3,
#   2,
#   3,
#   2,
#   2,
#   4,
#   4,
#   4,
#   2,
#   4,
#   2,
#   2,
#   3,
#   3,
#   2,
#   4,
#   3,
#   4,
#   2,
#   4,
#   2,
#   2,
#   4,
#   2,
#   2,
#   2,
#   4,
#   2,
#   3,
#   3,
#   3,
#   3,
#   3,
#   2,
#   2,
#   3,
#   2,
#   2,
#   4,
#   4,
#   4,
#   3,
#   4,
#   4,
#   4,
#   2,
#   2,
#   3,
#   2,
#   3,
#   2,
#   2,
#   3,
#   4,
#   3,
#   3,
#   2,
#   4,
#   3,
#   3,
#   4,
#   3,
#   2,
#   3,
#   2,
#   3,
#   4,
#   3,
#   3,
#   2,
#   2,
#   2,
#   3,
#   4,
#   2,
#   3,
#   2,
#   4,
#   4,
#   3,
#   4,
#   4,
#   3,
#   2,
#   3,
#   4,
#   3,
#   4,
#   4,
#   3,
#   3,
#   2,
#   4,
#   4,
#   2,
#   3,
#   2,
#   3,
#   4,
#   2,
#   3,
#   4,
#   4,
#   4,
#   3,
#   2,
#   3,
#   3,
#   2,
#   3,
#   2,
#   3,
#   2,
#   2,
#   2,
#   4,
#   4,
#   2,
#   3,
#   4,
#   2,
#   2,
#   4,
#   3,
#   3,
#   4,
#   3,
#   2,
#   3,
#   4,
#   3,
#   2,
#   3,
#   3,
#   3,
#   4,
#   3,
#   4,
#   3,
#   2,
#   3,
#   3],
#  [16,
#   11,
#   18,
#   16,
#   7,
#   15,
#   15,
#   20,
#   13,
#   20,
#   18,
#   6,
#   11,
#   8,
#   4,
#   20,
#   1,
#   19,
#   9,
#   12,
#   12,
#   4,
#   12,
#   12,
#   15,
#   16,
#   20,
#   11,
#   20,
#   16,
#   12,
#   15,
#   1,
#   1,
#   1,
#   12,
#   17,
#   20,
#   6,
#   19,
#   9,
#   16,
#   5,
#   3,
#   11,
#   19,
#   20,
#   12,
#   14,
#   3,
#   13,
#   13,
#   14,
#   18,
#   10,
#   13,
#   2,
#   3,
#   12,
#   12,
#   8,
#   12,
#   14,
#   11,
#   12,
#   20,
#   5,
#   1,
#   11,
#   4,
#   14,
#   7,
#   9,
#   2,
#   7,
#   15,
#   13,
#   9,
#   6,
#   4,
#   13,
#   19,
#   2,
#   17,
#   9,
#   15,
#   4,
#   19,
#   17,
#   14,
#   2,
#   14,
#   5,
#   13,
#   2,
#   7,
#   16,
#   12,
#   1,
#   16,
#   9,
#   16,
#   8,
#   13,
#   12,
#   18,
#   12,
#   4,
#   13,
#   11,
#   1,
#   14,
#   8,
#   8,
#   12,
#   6,
#   1,
#   4,
#   14,
#   14,
#   2,
#   6,
#   15,
#   11,
#   14,
#   11,
#   3,
#   18,
#   17,
#   16,
#   7,
#   13,
#   8,
#   12,
#   19,
#   11,
#   6,
#   9,
#   11,
#   12,
#   3,
#   12,
#   11,
#   12,
#   13,
#   14,
#   19,
#   13,
#   9,
#   4,
#   11,
#   2,
#   3,
#   14,
#   19,
#   13,
#   4,
#   19,
#   19,
#   12,
#   15,
#   13,
#   17,
#   13,
#   14,
#   19,
#   6,
#   11,
#   8,
#   15,
#   17,
#   9,
#   16,
#   6,
#   10,
#   4,
#   7,
#   4,
#   19,
#   3,
#   1,
#   20,
#   17,
#   7,
#   3,
#   4,
#   1,
#   15,
#   5,
#   5,
#   12,
#   14,
#   7,
#   14,
#   4,
#   6,
#   10,
#   10,
#   20,
#   4,
#   9,
#   15,
#   2,
#   18,
#   15,
#   9,
#   19,
#   20,
#   7,
#   2,
#   19,
#   14,
#   1,
#   4,
#   2,
#   9,
#   15,
#   12,
#   19,
#   17,
#   20,
#   12,
#   7,
#   6,
#   20,
#   12,
#   12,
#   14,
#   1,
#   5,
#   18,
#   13,
#   17,
#   6,
#   2,
#   10,
#   16,
#   6,
#   18,
#   3,
#   19,
#   2,
#   5,
#   8,
#   9,
#   19,
#   7,
#   12,
#   14,
#   15,
#   11,
#   6,
#   18,
#   1,
#   4,
#   1,
#   3,
#   2,
#   5,
#   15,
#   17,
#   6,
#   16,
#   16,
#   1,
#   7,
#   17,
#   15,
#   20,
#   5,
#   15,
#   8,
#   6,
#   1,
#   11,
#   11,
#   18,
#   14,
#   8,
#   12,
#   4,
#   17,
#   2,
#   4,
#   13,
#   8,
#   14,
#   3,
#   3,
#   1,
#   14,
#   19,
#   17,
#   12,
#   18,
#   20,
#   11,
#   7,
#   18,
#   8,
#   6,
#   1,
#   17,
#   1,
#   13,
#   2,
#   14,
#   5,
#   20,
#   8,
#   9,
#   10,
#   10,
#   13,
#   20,
#   14,
#   16,
#   16,
#   11,
#   1,
#   20,
#   17,
#   8,
#   5,
#   1,
#   17,
#   4,
#   17,
#   18,
#   10,
#   14,
#   5,
#   2,
#   15,
#   14,
#   5,
#   10,
#   18,
#   5,
#   5,
#   5,
#   18,
#   5,
#   12,
#   6,
#   20,
#   9,
#   4,
#   20,
#   17,
#   1,
#   17,
#   10,
#   17,
#   4,
#   4,
#   18,
#   10,
#   1,
#   7,
#   19,
#   7,
#   17,
#   14,
#   9,
#   6,
#   8,
#   12,
#   4,
#   8,
#   6,
#   15,
#   19,
#   7,
#   14,
#   8,
#   11,
#   1,
#   16,
#   14,
#   7,
#   16,
#   5,
#   9,
#   18,
#   6,
#   7,
#   18,
#   11,
#   18,
#   2,
#   10,
#   20,
#   6,
#   11,
#   15,
#   9,
#   11,
#   8,
#   14,
#   7,
#   14,
#   15,
#   14,
#   1,
#   8,
#   6,
#   20,
#   6,
#   1,
#   10,
#   4,
#   20,
#   9,
#   7,
#   7,
#   19,
#   3,
#   12,
#   18,
#   9,
#   6,
#   15,
#   14,
#   16,
#   12,
#   20,
#   4,
#   1,
#   9,
#   1,
#   7,
#   8,
#   16,
#   1,
#   4,
#   8,
#   17,
#   6,
#   10,
#   1,
#   19,
#   4,
#   3,
#   3,
#   3,
#   18,
#   17,
#   13,
#   13,
#   6,
#   12,
#   2,
#   13,
#   16,
#   15,
#   3,
#   13,
#   8,
#   2,
#   18,
#   9,
#   1,
#   7,
#   18,
#   3,
#   16,
#   20,
#   11,
#   17,
#   18,
#   5,
#   11,
#   16,
#   11,
#   5,
#   1,
#   7,
#   12,
#   6,
#   13,
#   3,
#   8,
#   16,
#   20,
#   8,
#   5,
#   9,
#   2,
#   20,
#   14,
#   15,
#   6,
#   7,
#   2,
#   19,
#   5,
#   11,
#   4,
#   14],
#  [20,
#   26,
#   30,
#   24,
#   27,
#   13,
#   18,
#   12,
#   10,
#   29,
#   14,
#   10,
#   28,
#   19,
#   17,
#   26,
#   11,
#   15,
#   25,
#   18,
#   15,
#   17,
#   27,
#   12,
#   28,
#   11,
#   18,
#   10,
#   19,
#   13,
#   13,
#   16,
#   19,
#   25,
#   13,
#   29,
#   22,
#   12,
#   12,
#   21,
#   10,
#   24,
#   12,
#   17,
#   30,
#   28,
#   24,
#   20,
#   22,
#   16,
#   28,
#   19,
#   15,
#   11,
#   28,
#   24,
#   27,
#   13,
#   24,
#   14,
#   14,
#   13,
#   10,
#   15,
#   28,
#   14,
#   19,
#   30,
#   23,
#   27,
#   29,
#   15,
#   23,
#   14,
#   15,
#   27,
#   28,
#   26,
#   23,
#   17,
#   10,
#   13,
#   18,
#   13,
#   21,
#   14,
#   18,
#   16,
#   26,
#   19,
#   21,
#   18,
#   19,
#   12,
#   20,
#   20,
#   21,
#   26,
#   25,
#   20,
#   15,
#   15,
#   27,
#   11,
#   29,
#   20,
#   18,
#   11,
#   13,
#   26,
#   24,
#   17,
#   13,
#   10,
#   10,
#   27,
#   15,
#   10,
#   22,
#   14,
#   12,
#   27,
#   28,
#   14,
#   18,
#   24,
#   28,
#   25,
#   17,
#   19,
#   25,
#   14,
#   16,
#   20,
#   15,
#   26,
#   29,
#   23,
#   19,
#   27,
#   24,
#   16,
#   16,
#   21,
#   29,
#   16,
#   16,
#   17,
#   29,
#   13,
#   18,
#   30,
#   20,
#   16,
#   22,
#   23,
#   23,
#   23,
#   11,
#   14,
#   18,
#   11,
#   26,
#   29,
#   29,
#   19,
#   13,
#   19,
#   10,
#   27,
#   12,
#   28,
#   29,
#   15,
#   13,
#   29,
#   15,
#   26,
#   16,
#   23,
#   24,
#   26,
#   23,
#   27,
#   28,
#   20,
#   22,
#   27,
#   30,
#   16,
#   25,
#   26,
#   17,
#   17,
#   25,
#   25,
#   12,
#   20,
#   19,
#   22,
#   28,
#   10,
#   18,
#   12,
#   12,
#   18,
#   20,
#   16,
#   15,
#   19,
#   11,
#   16,
#   23,
#   20,
#   28,
#   20,
#   30,
#   29,
#   20,
#   18,
#   25,
#   20,
#   17,
#   22,
#   27,
#   10,
#   23,
#   17,
#   14,
#   20,
#   23,
#   10,
#   13,
#   25,
#   17,
#   11,
#   24,
#   20,
#   29,
#   22,
#   12,
#   18,
#   14,
#   23,
#   11,
#   18,
#   18,
#   30,
#   11,
#   29,
#   16,
#   18,
#   10,
#   25,
#   10,
#   12,
#   18,
#   30,
#   16,
#   28,
#   27,
#   18,
#   26,
#   18,
#   14,
#   23,
#   17,
#   10,
#   23,
#   29,
#   26,
#   14,
#   22,
#   18,
#   21,
#   11,
#   17,
#   16,
#   20,
#   11,
#   22,
#   15,
#   14,
#   30,
#   24,
#   27,
#   11,
#   15,
#   19,
#   23,
#   29,
#   19,
#   22,
#   10,
#   23,
#   29,
#   30,
#   15,
#   11,
#   23,
#   11,
#   10,
#   11,
#   14,
#   21,
#   18,
#   16,
#   23,
#   16,
#   23,
#   23,
#   24,
#   27,
#   17,
#   22,
#   18,
#   22,
#   20,
#   16,
#   18,
#   20,
#   11,
#   12,
#   29,
#   26,
#   23,
#   14,
#   10,
#   25,
#   20,
#   28,
#   24,
#   26,
#   19,
#   29,
#   12,
#   22,
#   17,
#   18,
#   28,
#   19,
#   21,
#   22,
#   15,
#   18,
#   18,
#   18,
#   22,
#   29,
#   19,
#   14,
#   27,
#   25,
#   13,
#   21,
#   29,
#   23,
#   15,
#   28,
#   19,
#   30,
#   24,
#   29,
#   14,
#   16,
#   14,
#   23,
#   19,
#   12,
#   10,
#   18,
#   17,
#   26,
#   15,
#   22,
#   11,
#   29,
#   19,
#   23,
#   11,
#   30,
#   12,
#   25,
#   29,
#   19,
#   26,
#   16,
#   26,
#   22,
#   25,
#   19,
#   28,
#   29,
#   29,
#   21,
#   12,
#   10,
#   21,
#   21,
#   28,
#   29,
#   11,
#   13,
#   14,
#   15,
#   23,
#   15,
#   19,
#   17,
#   30,
#   22,
#   27,
#   24,
#   18,
#   13,
#   20,
#   15,
#   10,
#   21,
#   20,
#   21,
#   25,
#   24,
#   21,
#   25,
#   10,
#   14,
#   14,
#   30,
#   10,
#   15,
#   21,
#   14,
#   26,
#   17,
#   21,
#   14,
#   12,
#   21,
#   26,
#   13,
#   15,
#   24,
#   13,
#   26,
#   11,
#   16,
#   10,
#   11,
#   27,
#   12,
#   14,
#   14,
#   19,
#   21,
#   25,
#   21,
#   11,
#   30,
#   13,
#   11,
#   27,
#   17,
#   18,
#   29,
#   29,
#   14,
#   10,
#   25,
#   20,
#   20,
#   13,
#   19,
#   23,
#   21,
#   12,
#   27,
#   30,
#   18,
#   27,
#   19,
#   27,
#   15,
#   16,
#   29,
#   18,
#   22,
#   16,
#   12,
#   17,
#   23,
#   12,
#   28,
#   28,
#   24,
#   30,
#   21,
#   30,
#   18,
#   30],
#  [28,
#   35,
#   29,
#   28,
#   27,
#   25,
#   16,
#   15,
#   23,
#   29,
#   33,
#   35,
#   18,
#   31,
#   33,
#   19,
#   27,
#   30,
#   25,
#   19,
#   19,
#   15,
#   16,
#   31,
#   35,
#   23,
#   25,
#   21,
#   21,
#   29,
#   24,
#   31,
#   20,
#   28,
#   24,
#   31,
#   33,
#   28,
#   33,
#   23,
#   31,
#   34,
#   20,
#   18,
#   23,
#   28,
#   17,
#   15,
#   35,
#   29])

# %% [markdown]
# <h3>Ta khởi tạo 1 set gồm tất cả các lớp,
# <h3>Với mỗi vòng lặp ta chọn 1 lớp làm candidate, lấy ra khỏi set, nếu tìm được phòng và giờ ta thêm vào lời giải, nếu không ta loại candidate
#
# # Chọn lớp làm candidate (tham lam)
# - lớp có giáo viên đã được xếp ít lần nhất
# - lớp có giáo viên đã được xếp ít tiết nhất
# - lớp có số tiết ít nhất # t
# - lớp có sĩ số nhỏ nhất # s
# - nếu 4 điều kiện trên như nhau, chọn lớp có id nhỏ hơn
#
# # Chọn phòng cho lớp (tham lam)
# - phòng có kích thước nhỏ nhất lớn hơn sĩ số lớp (nếu không tồn tại, loại candidate)
# - phòng đã được xếp ít lần nhất
# - phòng đã được xếp ít tiết nhất
# - nếu 3 điều kiện trên như nhau, chọn phòng có id nhỏ hơn
#
# # Chọn giờ cho lớp
# - chọn giờ đầu tiên thỏa mãn tất cả ràng buộc (nếu không tồn tại, loại candidate)

# %% [markdown]
# # Thuật toán chọn tham lam
# với danh sách các candidate [a, b, ..., z]
# <br> và các đặc trưng tương ứng [Fa, Fb, ..., Fz]
#
# - ta lập các set đặc trưng là {F1, ..., Fn} (vì có thể nhiều candidate có đặc trưng giống nhau).
# - xếp thứ tự set trên theo mức ưu tiên
# (ví dụ muốn tìm ít nhất thì ta xếp dãy giảm dần, giá trị nhỏ hơn sẽ có chỉ số lớn hơn)
# - muốn lấy mức ưu tiên của candidate nào, ta lấy index của đặc trưng trong set
#
# <br> ví dụ: [1, 2, 3, 4, 5] có đặc trưng là [200, 300, 100, 200, 100]
# - ta lập set {100, 200, 300} và xếp lại thứ tự là {0: 300, 1: 200, 2: 100}
# - ta có độ ưu tiên tập candidate là [1, 0, 2, 1, 2], nên ta chọn phần tử id=3 vì id=3 < id=5
#
# <br> nếu chọn nhiều đặc trưng, ta cộng tổng mức ưu tiên các đặc trưng với nhau và chọn giá trị tổng lớn nhất làm candidate

# %% [markdown]
# # Cách chọn giờ bắt đầu cho lớp
# Ta liệt kê ra các set lưu các giờ phù hợp theo tiêu chí:
# - giờ để lớp đó nằm trong 1 buổi (ví dụ lớp 4 tiết thì ta chọn được tiết {1,2,3, 7,8,9, 13,14,15, ...} các buổi)
# - chọn giờ mà giáo viên thỏa mãn (chọn chuỗi t[i] tiết trống của giáo viên g[i]) (chuỗi tiết của giáo viên là 60 giá trị {0, 1}, ta tìm tất cả các subset t[i] giá trị 0, lưu lại giá trị tiết đầu tiên subset này) -> Duyệt O(n) = O(60)
# - Chọn giờ mà phòng thỏa mãn (tương tự với chọn giờ giáo viên)
#
# Ta lấy tập giao của 3 set trên và lấy giá trị nhỏ nhất

# %%
STARTING_OPTIONS = [i for i in range(60)]
ROOM_OPTIONS = [i for i in range(M)]


curr_solution = {}
curr_candidates = set()
assigned_g = {}
assigned_c = {}

def init():
    global curr_solution, curr_candidates, assigned_g, assigned_c

    curr_solution = {} # {class_id: (starting, room)}
    curr_candidates = set([i for i in range(N)])

    assigned_g = {
        i: { # teacher_id
            'num_assigned': 0, # số lần được xếp
            'periods': [0 for _ in range(60)], # vector tiết được xếp (1 được xếp, 0 chưa)
        } for i in set(g)
    }

    assigned_c = {
        i: { # room_id
            'num_assigned': 0, # số lần được xếp
            'periods': [0 for _ in range(60)], # vector tiết được xếp (1 được xếp, 0 chưa)
        } for i in range(len(c))
    }

# %% [markdown]
# # Hàm

# %%
# Các hàm chọn candidate cho lớp và phòng học

def creat_feature_dict(candidates_list, features_list):
    if len(candidates_list) != len(features_list):
        return {}
    
    return {
        candidates_list[i]: features_list[i]
        for i in range(len(candidates_list))
    }

def get_priority_from_features(features_dict, is_get_min=True): 
    # features_dict = {candidate: feature}
    features_set = list(set([features_dict[cand] for cand in features_dict]))
    features_set.sort(reverse=is_get_min)
    
    output = {} # {candidate: priority}
    for cand in features_dict:
        feat = features_dict[cand]
        output[cand] = features_set.index(feat)
    
    return output

def argmax(iterable):
    return max(enumerate(iterable), key=lambda x: x[1])[0]

def get_best_candidate(*priorities):
    candidates = list(priorities[0].keys())
    sum_priority = []

    for cand in candidates:
        sum_priority.append(sum([
            priority[cand] 
            if cand in priority
            else -MAX_VALUE
            for priority in priorities 
        ]))

    best_cand_idx = argmax(sum_priority)
    if sum_priority[best_cand_idx] < 0:
        return None
    return candidates[best_cand_idx]

# %%
# Các hàm chọn giờ 

def get_valid_startings(class_id):
    global N, M, t, g, s, c
    
    num_periods = t[class_id]
    valid_startings = set()
    
    for i in range(10): # 10 buổi
        temp = [(i * 6 + j) for j in range(6 - num_periods + 1)]
        valid_startings.update(temp)
    
    return valid_startings

def get_startings_with_teacher(class_id):
    global N, M, t, g, s, c, assigned_g

    teacher_id = g[class_id]
    num_periods = t[class_id]
    periods = assigned_g[teacher_id]['periods']

    feasible_startings = set()

    i = 0
    while i < len(periods):
        if periods[i] == 1:
            i += 1
            continue

        first_zero = i
        counting = 0
        while i < len(periods) and periods[i] == 0:
            counting += 1
            i += 1

        feasible_startings.update([
            first_zero + j 
            for j in range(counting - num_periods + 1)
        ])

    return feasible_startings
    

def get_startings_with_room(class_id, room_id):
    global N, M, t, g, s, c, assigned_c

    num_periods = t[class_id]
    periods = assigned_c[room_id]['periods']

    feasible_startings = set()

    i = 0
    while i < len(periods):
        if periods[i] == 1:
            i += 1
            continue

        first_zero = i
        counting = 0
        while i < len(periods) and periods[i] == 0:
            counting += 1
            i += 1

        feasible_startings.update([
            first_zero + j 
            for j in range(counting - num_periods + 1)
        ])

    return feasible_startings

# %% [markdown]
# # Cài đặt thuật toán

# %%
init()


while curr_candidates:
    # Chọn lớp
    class_candidates = list(curr_candidates)

    class_teacher_num_assigned = creat_feature_dict(
        class_candidates,
        [assigned_g[g[cand]]['num_assigned'] for cand in class_candidates]
    )
    class_teacher_num_assigned_priority = get_priority_from_features(class_teacher_num_assigned)

    class_teacher_sum_periods = creat_feature_dict(
        class_candidates,
        [sum(assigned_g[g[cand]]['periods']) for cand in class_candidates]
    )
    class_teacher_sum_periods_priority = get_priority_from_features(class_teacher_sum_periods)

    class_num_periods = creat_feature_dict(
        class_candidates,
        [t[cand] for cand in class_candidates]
    )
    class_num_periods_priority = get_priority_from_features(class_num_periods)

    class_num_pupils = creat_feature_dict(
        class_candidates,
        [s[cand] for cand in class_candidates]
    )
    class_num_pupils_priority = get_priority_from_features(class_num_pupils)

    curr_class = get_best_candidate(
        class_teacher_num_assigned_priority,
        class_teacher_sum_periods_priority,
        class_num_periods_priority,
        class_num_pupils_priority,
    )

    print('class:', curr_class)
    if curr_class is None:
        raise Exception('Candidate None!')

    curr_candidates.remove(curr_class)

    # Chọn phòng
    room_candidates = [idx for idx, size in enumerate(c)]

    room_size = dict(filter(
        lambda x: x[1] >= s[curr_class], 
        enumerate(c)
    ))
    if not room_size:
        print('No room valid!')
        continue
    room_size_priority = get_priority_from_features(room_size)

    room_num_assigned = creat_feature_dict(
        room_candidates,
        [assigned_c[cand]['num_assigned'] for cand in room_candidates]
    )
    room_num_assigned_priority = get_priority_from_features(room_num_assigned)
    
    room_sum_periods = creat_feature_dict(
        room_candidates,
        [sum(assigned_c[cand]['periods']) for cand in room_candidates]
    )
    room_sum_periods_priority = get_priority_from_features(room_sum_periods)
    
    curr_room = get_best_candidate(
        room_size_priority,
        room_num_assigned_priority,
        room_sum_periods_priority
    )

    if curr_room is None:
        raise Exception('Room None!')

    print('room:', curr_room)
    
    # Chọn giờ
    valid_startings = get_valid_startings(curr_class)
    startings_with_teacher = get_startings_with_teacher(curr_class)
    startings_with_room = get_startings_with_room(curr_class, curr_room)

    all_valid_startings = valid_startings & startings_with_teacher & startings_with_room

    if not all_valid_startings:
        print('No starting valid!')
        continue
    
    curr_starting = min(all_valid_startings)

    # Cập nhật biến
    assigned_g[g[curr_class]]['num_assigned'] += 1
    assigned_c[curr_room]['num_assigned'] += 1
    
    for temp in range(curr_starting, curr_starting + t[curr_class]):
        assigned_g[g[curr_class]]['periods'][temp] = 1
        assigned_c[curr_room]['periods'][temp] = 1

    curr_solution[curr_class] = (curr_starting, curr_room)
# Out:
# class: 8
# room: 7
# class: 27
# room: 21
# class: 40
# room: 47
# class: 168
# room: 6
# class: 225
# room: 22
# class: 252
# room: 7
# class: 267
# room: 21
# class: 301
# room: 46
# class: 62
# room: 47
# class: 117
# room: 6
# class: 210
# room: 12
# class: 300
# room: 22
# class: 417
# room: 43
# class: 447
# room: 15
# class: 467
# room: 19
# class: 120
# room: 20
# class: 369
# room: 46
# class: 381
# room: 7
# class: 429
# room: 12
# class: 475
# room: 21
# class: 16
# room: 32
# class: 53
# room: 42
# class: 80
# room: 20
# class: 235
# room: 22
# class: 293
# room: 27
# class: 414
# room: 28
# class: 11
# room: 43
# class: 201
# room: 47
# class: 240
# room: 6
# class: 254
# room: 8
# class: 379
# room: 15
# class: 25
# room: 19
# class: 42
# room: 25
# class: 275
# room: 32
# class: 327
# room: 39
# class: 488
# room: 42
# class: 37
# room: 44
# class: 244
# room: 46
# class: 298
# room: 7
# class: 445
# room: 12
# class: 113
# room: 21
# class: 231
# room: 28
# class: 425
# room: 27
# class: 158
# room: 30
# class: 176
# room: 34
# class: 196
# room: 5
# class: 255
# room: 18
# class: 107
# room: 26
# class: 204
# room: 4
# class: 248
# room: 6
# class: 335
# room: 8
# class: 73
# room: 15
# class: 396
# room: 16
# class: 7
# room: 20
# class: 29
# room: 25
# class: 38
# room: 34
# class: 203
# room: 44
# class: 297
# room: 46
# class: 302
# room: 0
# class: 457
# room: 3
# class: 23
# room: 7
# class: 322
# room: 22
# class: 395
# room: 33
# class: 57
# room: 37
# class: 123
# room: 39
# class: 368
# room: 42
# class: 440
# room: 43
# class: 452
# room: 45
# class: 471
# room: 47
# class: 174
# room: 2
# class: 286
# room: 4
# class: 17
# room: 9
# class: 114
# room: 18
# class: 161
# room: 19
# class: 460
# room: 26
# class: 466
# room: 28
# class: 71
# room: 32
# class: 166
# room: 12
# class: 321
# room: 15
# class: 375
# room: 21
# class: 491
# room: 27
# class: 65
# room: 30
# class: 242
# room: 46
# class: 459
# room: 5
# class: 34
# room: 7
# class: 81
# room: 8
# class: 149
# room: 22
# class: 208
# room: 25
# class: 287
# room: 29
# class: 63
# room: 42
# class: 100
# room: 44
# class: 101
# room: 47
# class: 401
# room: 49
# class: 448
# room: 3
# class: 357
# room: 16
# class: 450
# room: 17
# class: 5
# room: 33
# class: 10
# room: 45
# class: 30
# room: 0
# class: 353
# room: 6
# class: 426
# room: 9
# class: 443
# room: 13
# class: 60
# room: 20
# class: 258
# room: 23
# class: 326
# room: 28
# class: 74
# room: 29
# class: 134
# room: 31
# class: 228
# room: 34
# class: 282
# room: 35
# class: 61
# room: 37
# class: 93
# room: 40
# class: 142
# room: 10
# class: 437
# room: 14
# class: 112
# room: 36
# class: 205
# room: 38
# class: 263
# room: 43
# class: 403
# room: 2
# class: 427
# room: 19
# class: 189
# room: 23
# class: 207
# room: 30
# class: 402
# room: 31
# class: 406
# room: 32
# class: 441
# room: 39
# class: 49
# room: 41
# class: 264
# room: 45
# class: 279
# room: 46
# class: 103
# room: 49
# class: 222
# room: 1
# class: 250
# room: 3
# class: 52
# room: 4
# class: 170
# room: 11
# class: 271
# room: 12
# class: 308
# room: 17
# class: 364
# room: 18
# class: 446
# room: 24
# class: 483
# room: 26
# class: 82
# room: 27
# class: 173
# room: 33
# class: 329
# room: 38
# class: 416
# room: 40
# class: 21
# room: 48
# class: 43
# room: 0
# class: 303
# room: 47
# class: 373
# room: 5
# class: 85
# room: 6
# class: 432
# room: 9
# class: 108
# room: 10
# class: 119
# room: 13
# class: 150
# room: 14
# class: 159
# room: 15
# class: 202
# room: 16
# class: 338
# room: 20
# class: 487
# room: 22
# class: 489
# room: 25
# class: 79
# room: 28
# class: 197
# room: 35
# class: 276
# room: 36
# class: 365
# room: 21
# class: 83
# room: 37
# class: 129
# room: 44
# class: 350
# room: 43
# class: 87
# room: 2
# class: 234
# room: 8
# class: 256
# room: 19
# class: 318
# room: 29
# class: 386
# room: 30
# class: 20
# room: 7
# class: 132
# room: 32
# class: 345
# room: 34
# class: 14
# room: 39
# class: 31
# room: 41
# class: 131
# room: 42
# class: 277
# room: 1
# class: 66
# room: 4
# class: 317
# room: 17
# class: 337
# room: 12
# class: 404
# room: 23
# class: 413
# room: 27
# class: 59
# room: 38
# class: 232
# room: 45
# class: 241
# room: 48
# class: 408
# room: 0
# class: 436
# room: 3
# class: 26
# room: 9
# class: 146
# room: 10
# class: 152
# room: 11
# class: 363
# room: 14
# class: 463
# room: 15
# class: 410
# room: 16
# class: 472
# room: 24
# class: 6
# room: 25
# class: 92
# room: 28
# class: 99
# room: 31
# class: 116
# room: 33
# class: 305
# room: 40
# class: 498
# room: 49
# class: 281
# room: 46
# class: 346
# room: 1
# class: 141
# room: 18
# class: 192
# room: 20
# class: 261
# room: 26
# class: 288
# room: 32
# class: 313
# room: 34
# class: 470
# room: 35
# class: 482
# room: 47
# class: 160
# room: 41
# class: 178
# room: 43
# class: 198
# room: 44
# class: 138
# room: 5
# class: 145
# room: 6
# class: 209
# room: 8
# class: 430
# room: 7
# class: 454
# room: 13
# class: 86
# room: 17
# class: 340
# room: 19
# class: 343
# room: 21
# class: 341
# room: 23
# class: 344
# room: 30
# class: 371
# room: 36
# class: 51
# room: 37
# class: 84
# room: 39
# class: 246
# room: 42
# class: 311
# room: 48
# class: 336
# room: 0
# class: 407
# room: 2
# class: 0
# room: 11
# class: 94
# room: 24
# class: 128
# room: 15
# class: 227
# room: 25
# class: 245
# room: 27
# class: 485
# room: 29
# class: 167
# room: 38
# class: 239
# room: 40
# class: 384
# room: 4
# class: 434
# room: 46
# class: 147
# room: 9
# class: 370
# room: 12
# class: 420
# room: 16
# class: 451
# room: 22
# class: 213
# room: 18
# class: 229
# room: 31
# class: 306
# room: 33
# class: 333
# room: 35
# class: 359
# room: 41
# class: 390
# room: 45
# class: 28
# room: 49
# class: 165
# room: 3
# class: 96
# room: 8
# class: 219
# room: 10
# class: 319
# room: 13
# class: 456
# room: 14
# class: 13
# room: 23
# class: 215
# room: 26
# class: 274
# room: 28
# class: 419
# room: 34
# class: 237
# room: 37
# class: 90
# room: 39
# class: 95
# room: 44
# class: 153
# room: 48
# class: 185
# room: 1
# class: 218
# room: 24
# class: 342
# room: 25
# class: 453
# room: 20
# class: 462
# room: 27
# class: 478
# room: 29
# class: 266
# room: 30
# class: 394
# room: 36
# class: 251
# room: 32
# class: 320
# room: 42
# class: 352
# room: 2
# class: 378
# room: 5
# class: 105
# room: 16
# class: 179
# room: 17
# class: 291
# room: 15
# class: 422
# room: 35
# class: 496
# room: 40
# class: 106
# room: 43
# class: 137
# room: 41
# class: 278
# room: 0
# class: 193
# room: 46
# class: 199
# room: 3
# class: 273
# room: 19
# class: 312
# room: 11
# class: 415
# room: 13
# class: 480
# room: 18
# class: 68
# room: 33
# class: 349
# room: 28
# class: 41
# room: 37
# class: 310
# room: 38
# class: 391
# room: 45
# class: 439
# room: 4
# class: 39
# room: 39
# class: 140
# room: 9
# class: 211
# room: 6
# class: 268
# room: 8
# class: 347
# room: 10
# class: 486
# room: 24
# class: 19
# room: 12
# class: 223
# room: 25
# class: 294
# room: 29
# class: 388
# room: 31
# class: 494
# room: 34
# class: 32
# room: 36
# class: 236
# room: 48
# class: 299
# room: 44
# class: 455
# room: 49
# class: 72
# room: 5
# class: 314
# room: 14
# class: 354
# room: 23
# class: 431
# room: 26
# class: 469
# room: 27
# class: 154
# room: 35
# class: 304
# room: 41
# class: 316
# room: 1
# class: 272
# room: 2
# class: 307
# room: 3
# class: 309
# room: 11
# class: 332
# room: 17
# class: 54
# room: 33
# class: 75
# room: 37
# class: 397
# room: 28
# class: 47
# room: 30
# class: 230
# room: 38
# class: 111
# room: 20
# No starting valid!
# class: 124
# room: 20
# class: 206
# room: 32
# class: 377
# room: 15
# class: 444
# room: 40
# class: 366
# room: 39
# class: 435
# room: 45
# class: 46
# room: 10
# class: 221
# room: 42
# class: 325
# room: 8
# class: 331
# room: 16
# class: 361
# room: 29
# class: 438
# room: 25
# class: 155
# room: 44
# No starting valid!
# class: 474
# room: 44
# class: 18
# room: 48
# class: 55
# room: 0
# No starting valid!
# class: 356
# room: 0
# No starting valid!
# class: 398
# room: 0
# class: 473
# room: 9
# class: 24
# room: 13
# class: 56
# room: 24
# class: 89
# room: 19
# No starting valid!
# class: 91
# room: 43
# No starting valid!
# class: 127
# room: 18
# class: 184
# room: 31
# class: 284
# room: 34
# No starting valid!
# class: 315
# room: 43
# No starting valid!
# class: 36
# room: 34
# No starting valid!
# class: 133
# room: 34
# class: 157
# room: 35
# class: 186
# room: 36
# class: 265
# room: 49
# class: 292
# room: 4
# No starting valid!
# class: 382
# room: 4
# class: 412
# room: 5
# class: 449
# room: 11
# class: 48
# room: 14
# class: 169
# room: 17
# class: 182
# room: 23
# No starting valid!
# class: 280
# room: 23
# No starting valid!
# class: 481
# room: 23
# class: 88
# room: 37
# class: 156
# room: 30
# No starting valid!
# class: 214
# room: 2
# class: 442
# room: 30
# No starting valid!
# class: 3
# room: 30
# class: 77
# room: 3
# No starting valid!
# class: 78
# room: 39
# No starting valid!
# class: 187
# room: 3
# class: 194
# room: 16
# No starting valid!
# class: 195
# room: 16
# class: 200
# room: 29
# class: 328
# room: 26
# No starting valid!
# class: 389
# room: 26
# No starting valid!
# class: 69
# room: 40
# class: 125
# room: 26
# No starting valid!
# class: 243
# room: 39
# class: 387
# room: 41
# No starting valid!
# class: 423
# room: 27
# No starting valid!
# class: 468
# room: 26
# class: 15
# room: 41
# class: 50
# room: 1
# No starting valid!
# class: 76
# room: 1
# No starting valid!
# class: 118
# room: 8
# No starting valid!
# class: 143
# room: 27
# class: 162
# room: 1
# class: 212
# room: 8
# class: 374
# room: 10
# No starting valid!
# class: 126
# room: 10
# class: 144
# room: 13
# No starting valid!
# class: 233
# room: 13
# class: 238
# room: 31
# class: 372
# room: 33
# class: 490
# room: 35
# No starting valid!
# class: 130
# room: 35
# No starting valid!
# class: 148
# room: 35
# class: 163
# room: 36
# No starting valid!
# class: 177
# room: 36
# class: 4
# room: 38
# No starting valid!
# class: 135
# room: 38
# class: 262
# room: 45
# class: 270
# room: 4
# class: 323
# room: 11
# class: 405
# room: 14
# class: 183
# room: 24
# No starting valid!
# class: 220
# room: 18
# No starting valid!
# class: 351
# room: 24
# class: 33
# room: 18
# class: 181
# room: 37
# No starting valid!
# class: 191
# room: 37
# No starting valid!
# class: 226
# room: 25
# No starting valid!
# class: 367
# room: 19
# No starting valid!
# class: 383
# room: 48
# class: 385
# room: 37
# class: 464
# room: 2
# No starting valid!
# class: 493
# room: 0
# No starting valid!
# class: 2
# room: 17
# No starting valid!
# class: 70
# room: 2
# class: 224
# room: 0
# No starting valid!
# class: 269
# room: 9
# No starting valid!
# class: 339
# room: 0
# No starting valid!
# class: 392
# room: 9
# class: 400
# room: 17
# No starting valid!
# class: 418
# room: 28
# No starting valid!
# class: 465
# room: 17
# class: 1
# room: 0
# No starting valid!
# class: 151
# room: 23
# class: 380
# room: 40
# No starting valid!
# class: 424
# room: 0
# No starting valid!
# class: 433
# room: 0
# No starting valid!
# class: 477
# room: 40
# No starting valid!
# class: 45
# room: 0
# No starting valid!
# class: 58
# room: 34
# No starting valid!
# class: 109
# room: 0
# No starting valid!
# class: 110
# room: 34
# No starting valid!
# class: 122
# room: 0
# No starting valid!
# class: 188
# room: 40
# No starting valid!
# class: 253
# room: 0
# class: 260
# room: 16
# class: 411
# room: 29
# No starting valid!
# class: 421
# room: 5
# No starting valid!
# class: 461
# room: 29
# class: 22
# room: 40
# No starting valid!
# class: 97
# room: 40
# No starting valid!
# class: 164
# room: 40
# No starting valid!
# class: 175
# room: 40
# No starting valid!
# class: 190
# room: 5
# No starting valid!
# class: 249
# room: 40
# No starting valid!
# class: 257
# room: 40
# No starting valid!
# class: 259
# room: 40
# No starting valid!
# class: 355
# room: 40
# No starting valid!
# class: 360
# room: 40
# No starting valid!
# class: 376
# room: 40
# class: 399
# room: 41
# No starting valid!
# class: 479
# room: 41
# No starting valid!
# class: 9
# room: 41
# No starting valid!
# class: 102
# room: 41
# No starting valid!
# class: 121
# room: 41
# No starting valid!
# class: 290
# room: 41
# No starting valid!
# class: 295
# room: 41
# No starting valid!
# class: 330
# room: 41
# No starting valid!
# class: 348
# room: 41
# No starting valid!
# class: 484
# room: 41
# No starting valid!
# class: 495
# room: 41
# No starting valid!
# class: 64
# room: 41
# No starting valid!
# class: 115
# room: 41
# No starting valid!
# class: 139
# room: 41
# No starting valid!
# class: 172
# room: 41
# No starting valid!
# class: 217
# room: 41
# No starting valid!
# class: 289
# room: 25
# No starting valid!
# class: 334
# room: 41
# No starting valid!
# class: 492
# room: 41
# No starting valid!
# class: 499
# room: 41
# No starting valid!
# class: 104
# room: 41
# No starting valid!
# class: 136
# room: 41
# No starting valid!
# class: 180
# room: 34
# No starting valid!
# class: 216
# room: 41
# No starting valid!
# class: 283
# room: 41
# No starting valid!
# class: 285
# room: 41
# No starting valid!
# class: 393
# room: 41
# No starting valid!
# class: 12
# room: 41
# No starting valid!
# class: 35
# room: 41
# No starting valid!
# class: 98
# room: 5
# No starting valid!
# class: 296
# room: 41
# No starting valid!
# class: 324
# room: 41
# No starting valid!
# class: 362
# room: 41
# No starting valid!
# class: 497
# room: 41
# No starting valid!
# class: 247
# room: 41
# No starting valid!
# class: 458
# room: 41
# No starting valid!
# class: 44
# room: 41
# No starting valid!
# class: 171
# room: 41
# No starting valid!
# class: 476
# room: 41
# No starting valid!
# class: 358
# room: 41
# No starting valid!
# class: 409
# room: 41
# No starting valid!
# class: 428
# room: 41
# No starting valid!
# class: 67
# room: 41
# No starting valid!

# %%
curr_solution = dict(sorted(curr_solution.items()))

print(len(curr_solution))
for class_id, data in curr_solution.items():
    print(class_id+1, data[0]+1, data[1]+1)
# Out:
# 389
# 1 31 12
# 4 55 31
# 6 16 34
# 7 23 26
# 8 7 21
# 9 1 8
# 11 5 46
# 12 7 44
# 14 37 24
# 15 25 40
# 16 41 42
# 17 3 33
# 18 9 10
# 19 49 49
# 20 49 13
# 21 27 8
# 22 1 49
# 24 10 8
# 25 41 14
# 26 7 20
# 27 25 10
# 28 1 22
# 29 37 50
# 30 13 26
# 31 17 1
# 32 31 42
# 33 49 37
# 34 41 19
# 35 19 8
# 38 4 45
# 39 13 35
# 40 41 40
# 41 1 48
# 42 40 38
# 43 1 26
# 44 23 1
# 47 52 11
# 48 47 31
# 49 35 15
# 50 11 42
# 52 29 38
# 53 17 5
# 54 1 43
# 55 49 34
# 57 46 25
# 58 13 38
# 60 31 39
# 61 11 21
# 62 19 38
# 63 3 48
# 64 15 43
# 66 13 31
# 67 25 5
# 69 35 34
# 70 47 41
# 71 59 3
# 72 13 33
# 73 39 6
# 74 9 16
# 75 19 30
# 76 46 38
# 80 23 29
# 81 3 21
# 82 13 9
# 83 11 28
# 84 31 38
# 85 23 40
# 86 25 7
# 87 37 18
# 88 25 3
# 89 53 38
# 91 35 40
# 93 31 29
# 94 19 41
# 95 33 25
# 96 40 45
# 97 37 9
# 100 28 32
# 101 13 45
# 102 11 48
# 104 25 50
# 106 49 17
# 107 34 44
# 108 10 27
# 109 22 11
# 113 19 37
# 114 7 22
# 115 13 19
# 117 31 34
# 118 3 7
# 120 25 14
# 121 1 21
# 124 3 40
# 125 52 21
# 127 55 11
# 128 46 19
# 129 43 16
# 130 25 45
# 132 31 43
# 133 25 33
# 134 55 35
# 135 11 32
# 136 52 39
# 138 37 42
# 139 31 6
# 141 28 10
# 142 29 19
# 143 19 11
# 144 58 28
# 146 37 7
# 147 31 11
# 148 37 10
# 149 47 36
# 150 15 23
# 151 11 15
# 152 55 24
# 153 17 12
# 154 43 49
# 155 43 36
# 158 49 36
# 159 3 31
# 160 25 16
# 161 29 42
# 162 13 20
# 163 29 2
# 166 35 4
# 167 19 13
# 168 37 39
# 169 1 7
# 170 52 18
# 171 25 12
# 174 22 34
# 175 13 3
# 177 3 35
# 178 52 37
# 179 37 44
# 180 49 18
# 185 35 32
# 186 43 2
# 187 23 37
# 188 49 4
# 190 19 24
# 193 31 21
# 194 49 47
# 196 53 17
# 197 1 6
# 198 25 36
# 199 28 45
# 200 41 4
# 201 53 30
# 202 7 48
# 203 17 17
# 204 9 45
# 205 1 5
# 206 11 39
# 207 55 33
# 208 11 31
# 209 9 26
# 210 31 9
# 211 1 13
# 212 55 7
# 213 52 9
# 214 34 19
# 215 49 3
# 216 43 27
# 219 29 25
# 220 46 11
# 222 53 43
# 223 5 2
# 224 35 26
# 226 1 23
# 228 29 26
# 229 10 35
# 230 43 32
# 231 55 39
# 232 7 29
# 233 37 46
# 234 17 14
# 235 25 9
# 236 7 23
# 237 47 49
# 238 11 38
# 239 41 32
# 240 37 41
# 241 7 7
# 242 23 49
# 243 15 47
# 244 55 40
# 245 5 47
# 246 19 28
# 247 37 43
# 249 9 7
# 251 22 4
# 252 49 33
# 253 3 8
# 254 59 1
# 255 7 9
# 256 7 19
# 257 25 20
# 259 7 24
# 261 58 17
# 262 37 27
# 263 53 46
# 264 16 44
# 265 16 46
# 266 55 50
# 267 49 31
# 268 3 22
# 269 34 9
# 271 55 5
# 272 17 13
# 273 46 3
# 274 46 20
# 275 29 29
# 276 7 33
# 277 25 37
# 278 23 2
# 279 43 1
# 280 21 47
# 282 11 47
# 283 19 36
# 287 13 5
# 288 4 30
# 289 31 33
# 292 46 16
# 294 3 28
# 295 29 30
# 298 7 47
# 299 7 8
# 300 47 45
# 301 3 23
# 302 1 47
# 303 13 1
# 304 25 48
# 305 55 42
# 306 28 41
# 307 40 34
# 308 55 4
# 309 19 18
# 310 41 12
# 311 35 39
# 312 11 49
# 313 29 12
# 314 34 35
# 315 49 15
# 317 49 2
# 318 1 18
# 319 25 30
# 320 39 14
# 321 43 43
# 322 19 16
# 323 5 23
# 324 58 12
# 326 23 9
# 327 19 29
# 328 7 40
# 330 5 39
# 332 35 17
# 333 41 18
# 334 11 36
# 336 10 9
# 337 31 1
# 338 31 13
# 339 22 21
# 341 37 20
# 342 23 24
# 343 17 26
# 344 37 22
# 345 40 31
# 346 23 35
# 347 31 2
# 348 28 11
# 350 35 29
# 351 28 44
# 352 41 25
# 353 37 3
# 354 17 7
# 355 49 24
# 358 19 17
# 360 35 42
# 362 47 30
# 364 31 15
# 365 19 19
# 366 31 22
# 367 49 40
# 369 13 43
# 370 3 47
# 371 43 13
# 372 34 37
# 373 53 34
# 374 25 6
# 376 13 22
# 377 59 41
# 378 55 16
# 379 35 6
# 380 7 16
# 382 5 8
# 383 29 5
# 384 55 49
# 385 37 5
# 386 59 38
# 387 16 31
# 389 49 32
# 391 43 46
# 392 35 46
# 393 47 10
# 395 41 37
# 396 5 34
# 397 7 17
# 398 43 29
# 399 51 1
# 402 19 50
# 403 19 32
# 404 1 3
# 405 5 24
# 406 58 15
# 407 1 33
# 408 31 3
# 409 5 1
# 411 22 17
# 413 55 6
# 414 16 28
# 415 1 29
# 416 43 14
# 417 22 41
# 418 1 44
# 420 43 35
# 421 29 17
# 423 37 36
# 426 7 28
# 427 16 10
# 428 21 20
# 430 3 13
# 431 34 8
# 432 49 27
# 433 22 10
# 435 37 47
# 436 55 46
# 437 27 4
# 438 4 15
# 439 55 26
# 440 43 5
# 441 13 44
# 442 17 40
# 444 19 14
# 445 40 41
# 446 7 13
# 447 19 25
# 448 1 16
# 449 16 4
# 450 46 12
# 451 25 18
# 452 43 23
# 453 7 46
# 454 43 21
# 455 23 14
# 456 43 50
# 457 43 15
# 458 10 4
# 460 13 6
# 461 13 27
# 462 57 30
# 463 43 28
# 464 23 16
# 466 58 18
# 467 3 29
# 468 1 20
# 469 47 27
# 470 55 28
# 471 17 36
# 472 13 48
# 473 13 25
# 474 43 10
# 475 55 45
# 476 5 22
# 479 40 30
# 481 49 19
# 482 52 24
# 483 31 48
# 484 19 27
# 486 34 30
# 487 52 25
# 488 25 23
# 489 3 43
# 490 21 26
# 492 13 28
# 495 37 35
# 497 49 41
# 499 31 50
